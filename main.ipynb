# %%
cd /content/drive/MyDrive/projects/kaggle_diabetes/
# Out:
# /content/drive/MyDrive/projects/kaggle_diabetes

# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import pickle

# %% [markdown]
# # Data Analysis Phase

# %%
dataset = pd.read_csv("kaggle_diabetes.csv")
print(dataset.shape)
dataset.head()
# Out:
# (2000, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
dataset.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
target_column = "Outcome"
numerical_column = dataset.columns.drop(target_column)
output_rows = dataset[target_column]
dataset.drop(target_column,axis=1,inplace=True)

# %%
scaler = MinMaxScaler()
scaler.fit(dataset)
t_df = scaler.transform(dataset)

# %%
t_df
# Out:
# array([[0.11764706, 0.69346734, 0.50819672, ..., 0.41687345, 0.02092229,
#         0.43333333],
#        [0.        , 0.42211055, 0.67213115, ..., 0.47394541, 0.06618275,
#         0.03333333],
#        [0.        , 0.72864322, 0.        , ..., 0.5483871 , 0.23569599,
#         0.16666667],
#        ...,
#        [0.35294118, 0.42713568, 0.63934426, ..., 0.38709677, 0.12980359,
#         0.35      ],
#        [0.        , 0.64824121, 0.90163934, ..., 0.8325062 , 0.1029035 ,
#         0.08333333],
#        [0.11764706, 0.40703518, 0.59016393, ..., 0.37344913, 0.20025619,
#         0.06666667]])

# %%
X_train, X_test, y_train, y_test = train_test_split(t_df, output_rows, test_size=0.25, random_state=0)

# %%
print('X_train:',np.shape(X_train))
print('y_train:',np.shape(y_train))
print('X_test:',np.shape(X_test))
print('y_test:',np.shape(y_test))
# Out:
# X_train: (1500, 8)
# y_train: (1500,)
# X_test: (500, 8)
# y_test: (500,)

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_classifier = RandomForestClassifier(n_estimators=100)
random_forest_classifier.fit(X_train, y_train)
filename = 'diabetes-prediction-rfc-model.pkl'
pickle.dump(random_forest_classifier, open(filename, 'wb'))
loss_and_metrics = random_forest_classifier.score(X_test, y_test)
print(loss_and_metrics)
# Out:
# 0.984

# %%
from sklearn.ensemble import AdaBoostClassifier
adaBoost_classifier = AdaBoostClassifier(n_estimators=50)
adaBoost_classifier.fit(X_train, y_train)
filename = 'diabetes-prediction-abc-model.pkl'
pickle.dump(adaBoost_classifier, open(filename, 'wb'))
loss_and_metrics = adaBoost_classifier.score(X_test, y_test)
print(loss_and_metrics)
# Out:
# 0.806

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradient_boosting_classifier = GradientBoostingClassifier(n_estimators=100)
gradient_boosting_classifier.fit(X_train, y_train)
filename = 'diabetes-prediction-gbc-model.pkl'
pickle.dump(gradient_boosting_classifier, open(filename, 'wb'))
loss_and_metrics = gradient_boosting_classifier.score(X_test, y_test)
print(loss_and_metrics)
# Out:
# 0.878

# %%
classifier = pickle.load(open("diabetes-prediction-rfc-model.pkl", 'rb'))
